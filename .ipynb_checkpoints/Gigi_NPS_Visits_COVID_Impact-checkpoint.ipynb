# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.ioff()

file_path="Data_Resources/park_type_and_region.csv"
parkcode_df = pd.read_csv(file_path)
#parkcode_df.head()

file_path="Data_Resources/monthly_park_visits.csv"
monthly_visits_df = pd.read_csv(file_path)
monthly_visits_df.isnull().sum()
# Out:
# parkCode      0
# Park Name     0
# JAN_2019     10
# FEB_2019      6
# MAR_2019      5
# APR_2019      5
# MAY_2019      2
# JUN_2019      0
# JUL_2019      0
# AUG_2019      0
# SEP_2019      0
# OCT_2019      0
# NOV_2019      0
# DEC_2019      0
# JAN_2020     10
# FEB_2020      6
# MAR_2020      5
# APR_2020      5
# MAY_2020      2
# JUN_2020      0
# JUL_2020      0
# AUG_2020      0
# SEP_2020      0
# OCT_2020      0
# NOV_2020      0
# DEC_2020      0
# dtype: int64

# %%
monthly_visits_df = monthly_visits_df.fillna(0)

# %%
monthly_visits_df.isnull().sum()
# Out:
# parkCode     0
# Park Name    0
# JAN_2019     0
# FEB_2019     0
# MAR_2019     0
# APR_2019     0
# MAY_2019     0
# JUN_2019     0
# JUL_2019     0
# AUG_2019     0
# SEP_2019     0
# OCT_2019     0
# NOV_2019     0
# DEC_2019     0
# JAN_2020     0
# FEB_2020     0
# MAR_2020     0
# APR_2020     0
# MAY_2020     0
# JUN_2020     0
# JUL_2020     0
# AUG_2020     0
# SEP_2020     0
# OCT_2020     0
# NOV_2020     0
# DEC_2020     0
# dtype: int64

# %%
monthly_visits_df.columns
# Out:
# Index(['parkCode', 'Park Name', 'JAN_2019', 'FEB_2019', 'MAR_2019', 'APR_2019',
#        'MAY_2019', 'JUN_2019', 'JUL_2019', 'AUG_2019', 'SEP_2019', 'OCT_2019',
#        'NOV_2019', 'DEC_2019', 'JAN_2020', 'FEB_2020', 'MAR_2020', 'APR_2020',
#        'MAY_2020', 'JUN_2020', 'JUL_2020', 'AUG_2020', 'SEP_2020', 'OCT_2020',
#        'NOV_2020', 'DEC_2020'],
#       dtype='object')

# %%
month_df = pd.merge(monthly_visits_df, parkcode_df, on="parkCode", how="outer")
month_df
# Out:
#     parkCode                       Park Name  JAN_2019  FEB_2019  MAR_2019  \
# 0       ABLI  Abraham Lincoln Birthplace NHP    1939.0    6534.0   14566.0
# 1       ACAD                       Acadia NP    8532.0    9154.0   20161.0
# 2       ADAM                       Adams NHP      27.0     179.0     253.0
# 3       AFBG        African Burial Ground NM      96.0    1571.0    1395.0
# 4       AGFO            Agate Fossil Beds NM       0.0      94.0     401.0
# ..       ...                             ...       ...       ...       ...
# 374     YELL                  Yellowstone NP   33896.0   31650.0   28695.0
# 375     YOSE                     Yosemite NP  116746.0  111665.0  173610.0
# 376     YUCH      Yukon-Charley Rivers NPRES       6.0      72.0      46.0
# 377     ZION                         Zion NP   98828.0  102269.0  296316.0
# 378     ARHO                             NaN       NaN       NaN       NaN
#
#      APR_2019  MAY_2019  JUN_2019  JUL_2019  AUG_2019  ...  MAY_2020  \
# 0     16496.0   24646.0   26854.0   37334.0   34816.0  ...   21102.0
# 1     68046.0  226156.0  490720.0  756439.0  759735.0  ...  103120.0
# 2       537.0   13187.0   23963.0   75333.0   26011.0  ...     743.0
# 3      5022.0    5482.0    4621.0    5520.0    4332.0  ...       0.0
# 4       391.0    2188.0    3276.0    4222.0    2775.0  ...     310.0
# ..        ...       ...       ...       ...       ...  ...       ...
# 374   48150.0  434385.0  781853.0  936062.0  820006.0  ...   46219.0
# 375  297207.0  393004.0  496625.0  717462.0  703153.0  ...       0.0
# 376      37.0      14.0     182.0     354.0     246.0  ...      25.0
# 377  372349.0  529553.0  594896.0  629802.0  535322.0  ...  178194.0
# 378       NaN       NaN       NaN       NaN       NaN  ...       NaN
#
#      JUN_2020  JUL_2020  AUG_2020  SEP_2020  OCT_2020  NOV_2020  DEC_2020  \
# 0     29111.0   37249.0   31290.0   29134.0   18615.0   12147.0    7472.0
# 1    201156.0  493971.0  681746.0  500320.0  480859.0   76251.0   21260.0
# 2       759.0     460.0     520.0     575.0     500.0     491.0     544.0
# 3         0.0       0.0       0.0       0.0     446.0     446.0     116.0
# 4       834.0    2377.0    1686.0    1558.0     978.0     252.0     121.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 374  573205.0  955645.0  881829.0  837114.0  359889.0   24132.0   28643.0
# 375  236534.0  501068.0  375226.0  258561.0  249827.0  136799.0  117454.0
# 376      72.0     149.0     164.0      88.0      89.0       8.0      20.0
# 377  377425.0  449518.0  450183.0  520987.0  559342.0  319853.0  227244.0
# 378       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#                      parkType             Region
# 0    National Historical Park         Southeast
# 1               National Park         Northeast
# 2    National Historical Park         Northeast
# 3           National Monument         Northeast
# 4           National Monument           Midwest
# ..                        ...                ...
# 374             National Park     Intermountain
# 375             National Park      Pacific West
# 376         National Preserve             Alaska
# 377             National Park     Intermountain
# 378         National Memorial  National Capital
#
# [379 rows x 28 columns]

# %%
month_df = month_df.iloc[:-1]
month_df
# Out:
#     parkCode                       Park Name  JAN_2019  FEB_2019  MAR_2019  \
# 0       ABLI  Abraham Lincoln Birthplace NHP    1939.0    6534.0   14566.0
# 1       ACAD                       Acadia NP    8532.0    9154.0   20161.0
# 2       ADAM                       Adams NHP      27.0     179.0     253.0
# 3       AFBG        African Burial Ground NM      96.0    1571.0    1395.0
# 4       AGFO            Agate Fossil Beds NM       0.0      94.0     401.0
# ..       ...                             ...       ...       ...       ...
# 373     WUPA                      Wupatki NM     724.0    4243.0   17447.0
# 374     YELL                  Yellowstone NP   33896.0   31650.0   28695.0
# 375     YOSE                     Yosemite NP  116746.0  111665.0  173610.0
# 376     YUCH      Yukon-Charley Rivers NPRES       6.0      72.0      46.0
# 377     ZION                         Zion NP   98828.0  102269.0  296316.0
#
#      APR_2019  MAY_2019  JUN_2019  JUL_2019  AUG_2019  ...  MAY_2020  \
# 0     16496.0   24646.0   26854.0   37334.0   34816.0  ...   21102.0
# 1     68046.0  226156.0  490720.0  756439.0  759735.0  ...  103120.0
# 2       537.0   13187.0   23963.0   75333.0   26011.0  ...     743.0
# 3      5022.0    5482.0    4621.0    5520.0    4332.0  ...       0.0
# 4       391.0    2188.0    3276.0    4222.0    2775.0  ...     310.0
# ..        ...       ...       ...       ...       ...  ...       ...
# 373   14767.0   14117.0   27113.0   26993.0   24528.0  ...       0.0
# 374   48150.0  434385.0  781853.0  936062.0  820006.0  ...   46219.0
# 375  297207.0  393004.0  496625.0  717462.0  703153.0  ...       0.0
# 376      37.0      14.0     182.0     354.0     246.0  ...      25.0
# 377  372349.0  529553.0  594896.0  629802.0  535322.0  ...  178194.0
#
#      JUN_2020  JUL_2020  AUG_2020  SEP_2020  OCT_2020  NOV_2020  DEC_2020  \
# 0     29111.0   37249.0   31290.0   29134.0   18615.0   12147.0    7472.0
# 1    201156.0  493971.0  681746.0  500320.0  480859.0   76251.0   21260.0
# 2       759.0     460.0     520.0     575.0     500.0     491.0     544.0
# 3         0.0       0.0       0.0       0.0     446.0     446.0     116.0
# 4       834.0    2377.0    1686.0    1558.0     978.0     252.0     121.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 373   17432.0   19276.0   22804.0   24198.0   17215.0   12067.0    8339.0
# 374  573205.0  955645.0  881829.0  837114.0  359889.0   24132.0   28643.0
# 375  236534.0  501068.0  375226.0  258561.0  249827.0  136799.0  117454.0
# 376      72.0     149.0     164.0      88.0      89.0       8.0      20.0
# 377  377425.0  449518.0  450183.0  520987.0  559342.0  319853.0  227244.0
#
#                      parkType          Region
# 0    National Historical Park      Southeast
# 1               National Park      Northeast
# 2    National Historical Park      Northeast
# 3           National Monument      Northeast
# 4           National Monument        Midwest
# ..                        ...             ...
# 373         National Monument  Intermountain
# 374             National Park  Intermountain
# 375             National Park   Pacific West
# 376         National Preserve          Alaska
# 377             National Park  Intermountain
#
# [378 rows x 28 columns]

# %%
# jan2019 = month_df.groupby('parkType')['JAN_2019'].sum()
# feb2019 = month_df.groupby('parkType')['FEB_2019'].sum()
# mar2019 = month_df.groupby('parkType')['MAR_2019'].sum()
# apr2019 = month_df.groupby('parkType')['APR_2019'].sum()
# may2019 = month_df.groupby('parkType')['MAY_2019'].sum()
# jun2019 = month_df.groupby('parkType')['JUN_2019'].sum()
# jul2019 = month_df.groupby('parkType')['JUL_2019'].sum()
# aug2019 = month_df.groupby('parkType')['AUG_2019'].sum()
# sep2019 = month_df.groupby('parkType')['SEP_2019'].sum()
# oct2019 = month_df.groupby('parkType')['OCT_2019'].sum()
# nov2019 = month_df.groupby('parkType')['NOV_2019'].sum()
# dec2019 = month_df.groupby('parkType')['DEC_2019'].sum()
# jun2019

# %%
month_df['total_2019']=month_df.iloc[:, 2:14].sum(axis=1)
month_df
# Out:
# <ipython-input-7-e8d829eb078d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_df['total_2019']=month_df.iloc[:, 2:14].sum(axis=1)
#     parkCode                       Park Name  JAN_2019  FEB_2019  MAR_2019  \
# 0       ABLI  Abraham Lincoln Birthplace NHP    1939.0    6534.0   14566.0
# 1       ACAD                       Acadia NP    8532.0    9154.0   20161.0
# 2       ADAM                       Adams NHP      27.0     179.0     253.0
# 3       AFBG        African Burial Ground NM      96.0    1571.0    1395.0
# 4       AGFO            Agate Fossil Beds NM       0.0      94.0     401.0
# ..       ...                             ...       ...       ...       ...
# 373     WUPA                      Wupatki NM     724.0    4243.0   17447.0
# 374     YELL                  Yellowstone NP   33896.0   31650.0   28695.0
# 375     YOSE                     Yosemite NP  116746.0  111665.0  173610.0
# 376     YUCH      Yukon-Charley Rivers NPRES       6.0      72.0      46.0
# 377     ZION                         Zion NP   98828.0  102269.0  296316.0
#
#      APR_2019  MAY_2019  JUN_2019  JUL_2019  AUG_2019  ...  JUN_2020  \
# 0     16496.0   24646.0   26854.0   37334.0   34816.0  ...   29111.0
# 1     68046.0  226156.0  490720.0  756439.0  759735.0  ...  201156.0
# 2       537.0   13187.0   23963.0   75333.0   26011.0  ...     759.0
# 3      5022.0    5482.0    4621.0    5520.0    4332.0  ...       0.0
# 4       391.0    2188.0    3276.0    4222.0    2775.0  ...     834.0
# ..        ...       ...       ...       ...       ...  ...       ...
# 373   14767.0   14117.0   27113.0   26993.0   24528.0  ...   17432.0
# 374   48150.0  434385.0  781853.0  936062.0  820006.0  ...  573205.0
# 375  297207.0  393004.0  496625.0  717462.0  703153.0  ...  236534.0
# 376      37.0      14.0     182.0     354.0     246.0  ...      72.0
# 377  372349.0  529553.0  594896.0  629802.0  535322.0  ...  377425.0
#
#      JUL_2020  AUG_2020  SEP_2020  OCT_2020  NOV_2020  DEC_2020  \
# 0     37249.0   31290.0   29134.0   18615.0   12147.0    7472.0
# 1    493971.0  681746.0  500320.0  480859.0   76251.0   21260.0
# 2       460.0     520.0     575.0     500.0     491.0     544.0
# 3         0.0       0.0       0.0     446.0     446.0     116.0
# 4      2377.0    1686.0    1558.0     978.0     252.0     121.0
# ..        ...       ...       ...       ...       ...       ...
# 373   19276.0   22804.0   24198.0   17215.0   12067.0    8339.0
# 374  955645.0  881829.0  837114.0  359889.0   24132.0   28643.0
# 375  501068.0  375226.0  258561.0  249827.0  136799.0  117454.0
# 376     149.0     164.0      88.0      89.0       8.0      20.0
# 377  449518.0  450183.0  520987.0  559342.0  319853.0  227244.0
#
#                      parkType          Region  total_2019
# 0    National Historical Park      Southeast     238226.0
# 1               National Park      Northeast    3437286.0
# 2    National Historical Park      Northeast     187400.0
# 3           National Monument      Northeast      47427.0
# 4           National Monument        Midwest      16657.0
# ..                        ...             ...         ...
# 373         National Monument  Intermountain     187059.0
# 374             National Park  Intermountain    4020288.0
# 375             National Park   Pacific West    4422861.0
# 376         National Preserve          Alaska      1114.0
# 377             National Park  Intermountain    4488268.0
#
# [378 rows x 29 columns]

# %%
month_df['total_2020']=month_df.iloc[:, 14:27].sum(axis=1)
month_df
# Out:
# <ipython-input-8-5fcdc33e0cca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_df['total_2020']=month_df.iloc[:, 14:27].sum(axis=1)
#     parkCode                       Park Name  JAN_2019  FEB_2019  MAR_2019  \
# 0       ABLI  Abraham Lincoln Birthplace NHP    1939.0    6534.0   14566.0
# 1       ACAD                       Acadia NP    8532.0    9154.0   20161.0
# 2       ADAM                       Adams NHP      27.0     179.0     253.0
# 3       AFBG        African Burial Ground NM      96.0    1571.0    1395.0
# 4       AGFO            Agate Fossil Beds NM       0.0      94.0     401.0
# ..       ...                             ...       ...       ...       ...
# 373     WUPA                      Wupatki NM     724.0    4243.0   17447.0
# 374     YELL                  Yellowstone NP   33896.0   31650.0   28695.0
# 375     YOSE                     Yosemite NP  116746.0  111665.0  173610.0
# 376     YUCH      Yukon-Charley Rivers NPRES       6.0      72.0      46.0
# 377     ZION                         Zion NP   98828.0  102269.0  296316.0
#
#      APR_2019  MAY_2019  JUN_2019  JUL_2019  AUG_2019  ...  JUL_2020  \
# 0     16496.0   24646.0   26854.0   37334.0   34816.0  ...   37249.0
# 1     68046.0  226156.0  490720.0  756439.0  759735.0  ...  493971.0
# 2       537.0   13187.0   23963.0   75333.0   26011.0  ...     460.0
# 3      5022.0    5482.0    4621.0    5520.0    4332.0  ...       0.0
# 4       391.0    2188.0    3276.0    4222.0    2775.0  ...    2377.0
# ..        ...       ...       ...       ...       ...  ...       ...
# 373   14767.0   14117.0   27113.0   26993.0   24528.0  ...   19276.0
# 374   48150.0  434385.0  781853.0  936062.0  820006.0  ...  955645.0
# 375  297207.0  393004.0  496625.0  717462.0  703153.0  ...  501068.0
# 376      37.0      14.0     182.0     354.0     246.0  ...     149.0
# 377  372349.0  529553.0  594896.0  629802.0  535322.0  ...  449518.0
#
#      AUG_2020  SEP_2020  OCT_2020  NOV_2020  DEC_2020  \
# 0     31290.0   29134.0   18615.0   12147.0    7472.0
# 1    681746.0  500320.0  480859.0   76251.0   21260.0
# 2       520.0     575.0     500.0     491.0     544.0
# 3         0.0       0.0     446.0     446.0     116.0
# 4      1686.0    1558.0     978.0     252.0     121.0
# ..        ...       ...       ...       ...       ...
# 373   22804.0   24198.0   17215.0   12067.0    8339.0
# 374  881829.0  837114.0  359889.0   24132.0   28643.0
# 375  375226.0  258561.0  249827.0  136799.0  117454.0
# 376     164.0      88.0      89.0       8.0      20.0
# 377  450183.0  520987.0  559342.0  319853.0  227244.0
#
#                      parkType          Region  total_2019  total_2020
# 0    National Historical Park      Southeast     238226.0    228141.0
# 1               National Park      Northeast    3437286.0   2669034.0
# 2    National Historical Park      Northeast     187400.0      6937.0
# 3           National Monument      Northeast      47427.0      7908.0
# 4           National Monument        Midwest      16657.0      8722.0
# ..                        ...             ...         ...         ...
# 373         National Monument  Intermountain     187059.0    146074.0
# 374             National Park  Intermountain    4020288.0   3806306.0
# 375             National Park   Pacific West    4422861.0   2268313.0
# 376         National Preserve          Alaska      1114.0       666.0
# 377             National Park  Intermountain    4488268.0   3591254.0
#
# [378 rows x 30 columns]

# %%
total_sum2019 = month_df['total_2019'].sum()
total_sum2019
# Out:
# 327516619.0

# %%
total_sum2020 = month_df['total_2020'].sum()
total_sum2020
# Out:
# 235972454.0

# %%
# summer2019 = jun2019 + jul2019 + aug2019
# summer2019
# summer2019 = (month_df['JUN_2019']+month_df['AUG_2019']+ month_df['AUG_2019']).sum()
# summer2019
jun2019 = month_df.groupby('parkType')['JUN_2019'].sum()
jul2019 = month_df.groupby('parkType')['JUL_2019'].sum()
aug2019 = month_df.groupby('parkType')['AUG_2019'].sum()
summer2019 = jun2019 + jul2019 + aug2019
summer2019.sort_values()
# Out:
# parkType
# International Historic Site         6972.0
# National Reserve                   54177.0
# National Wild & Scenic River      732025.0
# National Battlefield              784855.0
# National Preserve                1015178.0
# National Battlefield Park        1152967.0
# National Military Park           1332896.0
# National River                   1688629.0
# National Lakeshore               1802531.0
# National Historic Site           3093903.0
# Park (Other)                     3201810.0
# National Seashore                7960714.0
# National Monument               10030522.0
# National Parkway                10402600.0
# National Memorial               12552395.0
# National Historical Park        13095280.0
# National Recreation Area        18612413.0
# National Park                   40226378.0
# dtype: float64

# %%
jun2020 = month_df.groupby('parkType')['JUN_2020'].sum()
jul2020 = month_df.groupby('parkType')['JUL_2020'].sum()
aug2020 = month_df.groupby('parkType')['AUG_2020'].sum()
#summer2020 = (month_df['JUN_2020']+month_df['AUG_2020']+ month_df['AUG_2020']).sum()
#summer2020

summer2020 = jun2020 + jul2020 + aug2020
summer2020.sort_values()
# Out:
# parkType
# International Historic Site         3923.0
# National Reserve                   48187.0
# National Battlefield              603402.0
# National Wild & Scenic River      869903.0
# National Military Park            925031.0
# National Preserve                1025094.0
# National Historic Site           1080205.0
# National Battlefield Park        1081845.0
# Park (Other)                     1566027.0
# National River                   1943731.0
# National Lakeshore               2148018.0
# National Monument                2908608.0
# National Memorial                4441835.0
# National Historical Park         5739228.0
# National Seashore                7961010.0
# National Parkway                 9823600.0
# National Recreation Area        17871213.0
# National Park                   29664949.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
w = 0.4

x = ["Park", "Recreation Area", "Historical Park", "Monument"] #"Total"
data2019 = [38466358, 18612413, 13095280, 12552395] #327516619
data2020 = [28387823, 17871213, 5739228, 2908608] #235972454

bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]

plt.bar(bar1, data2019,w,label="2019", color="tan")
plt.bar(bar2, data2020,w,label="2020", color="forestgreen")

plt.xlabel("Park Types")
plt.ylabel("Number of Visits")
plt.title("COVID-19 Impact: Summer 2019 v. 2020")
plt.xticks(bar1+w/2, x)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.patches as mpatches

x_labels = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
years = {'2019': 'tan', '2020': 'forestgreen'}

regions = month_df['Region'].unique().tolist()

region_data = {}
for c_year in years:
    for x_label in x_labels:
        month_year = x_label+'_'+c_year
        region_data[month_year] = month_df.groupby('Region')[month_year].sum()

for region in regions:
    handles = []
    for c_year in years:
        y_data = []
        for x_label in x_labels:
            month_year = x_label+'_'+c_year
            y_data.append(region_data[month_year][region])
        color = years[c_year]
        plt.plot(y_data, color=color)
        handles.append(mpatches.Patch(color=color, label=c_year))

    plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
    plt.title(region)
    plt.xlabel('Month')
    plt.ylabel('Number of Visits')
    plt.xticks(np.arange(len(x_labels)), x_labels)
    plt.legend(handles=handles)
    plt.rcParams['figure.figsize'] = [8,6]
    plt.grid()
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
